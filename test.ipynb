# %%
import pickle
from utils.image_processing import compute_R

# %%
with open('input_0219_0224_0225_0226_0227_contour_th_128_pixels_grades_images_aligned.pkl', 'rb') as f:
    input_all = pickle.load(f)

grade_data = input_all[1]
images = input_all[2]

# %%
R_images = {}
for source in images:
    for n in range(len(images[source][0])):
        R_img = compute_R(images[source][0][n], images[source][1][n], input='images', method='a', const=[5, 20])
        R_images[source][n] = R_img
    print(source)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 R_images = {}
#       2 for source in images:
# ----> 3     for n in len(images[source][0]):
#       4         R_img = compute_R(images[source][0][n], images[source][1][n], input='images', method='a', const=[5, 20])
#       5         R_images[source][n] = R_img
#
# TypeError: 'int' object is not iterable

# %%
len(images[source][0])
# Out:
# 98

# %%
images['source_0'][0]
# Out:
# [array([[255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#  array([[255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#  array([[255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#  array([[255, 255, 255, ..., 255, 255, 255],
# ...

# %%
images['source_0'][0][68].shape
# Out:
# (74, 32)

# %%
grade_data
# Out:
#      Sample No.  Fe_grade  Zn_grade  Pb_grade  S_grade  weight    source  \
# 0             1    30.130     0.031     0.063    34.83    39.9  source_0
# 1             2     7.446     0.784     2.125     6.72    50.4  source_0
# 2             3    30.480     0.058     0.045    31.65    69.8  source_0
# 3             4    31.200     0.089     0.319    31.76    48.8  source_0
# 4             5     9.662    10.170     1.353    11.81    48.7  source_0
# ..          ...       ...       ...       ...      ...     ...       ...
# 704         101     8.414     0.065     0.037     0.00    47.3  source_4
# 705         102     4.789     0.065     0.022     0.00    46.3  source_4
# 706         103     4.882     7.838     0.509     0.00    34.8  source_4
# 707         104    23.920    22.030     4.930     0.00    29.7  source_4
# 708         105     6.580     0.367     0.258     0.00    32.8  source_4
#
#      Zn_Pb_grade
# 0          0.094
# 1          2.909
# 2          0.103
# 3          0.408
# ...

# %%
low_energy_imgs = []
high_energy_imgs = []
for source_imgs in images:
    print(source_imgs)
    low_energy_imgs.extend(images[source_imgs][0])
    high_energy_imgs.extend(images[source_imgs][1])
# Out:
# source_0
# source_1
# source_2
# source_3
# source_4

# %%
len(low_energy_imgs)
# Out:
# 685
